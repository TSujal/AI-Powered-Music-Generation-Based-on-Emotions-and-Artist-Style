# %% [markdown]
# ### GPU setup

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %% [markdown]
# ### Important Library...

# %%
# !pip install beautifulsoup4

# %%
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import requests
from bs4 import BeautifulSoup
from sklearn.utils import shuffle
from collections import Counter

# %%
df = pd.read_csv("/content/MY_MUSIC_URLS.csv")
df = df.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#           Artist Country             Song  \
# 0      Lady Gaga     USA       Sour Candy
# 1    Karan Aujla   India       Tere Karke
# 2   Taylor Swift     USA    The Albatross
# 3          Drake     USA   Virginia Beach
# 4  Billie Eilish     USA  Bad Guy (Remix)
#
#                                            url
# 0  https://www.youtube.com/watch?v=fnPn6At3v28
# 1  https://www.youtube.com/watch?v=k85UB5b6pJU
# 2  https://www.youtube.com/watch?v=4wOsiM2T_xc
# 3  https://www.youtube.com/watch?v=k20wnICXpps
# 4  https://www.youtube.com/watch?v=9Wb-oJ6WVy0

# %%
df.isna().sum()
# Out:
# Artist     0
# Country    0
# Song       0
# url        0
# dtype: int64

# %%
len(df)
# Out:
# 840

# %%
#data is been properly divided amongst all the singers as all of them have similar number of songs...
df["Artist"].value_counts()
# Out:
# Artist
# Lady Gaga           20
# Sukhwinder Singh    20
# Atif Aslam          20
# Sunidhi Chauhan     20
# Post Malone         20
# Jonita Gandhi       20
# Rihanna             20
# Demi Lovato         20
# Vishal Mishra       20
# Shawn Mendes        20
# Armaan Malik        20
# Karan Aujla         20
# Jubin Nautiyal      20
# Coldplay            20
# Katy Perry          20
# Eminem              20
# Arijit Singh        20
# Ed Sheeran          20
# Ariana Grande       20
# Sia                 20
# Sachin Sanghvi      20
# The Weeknd          20
# Neeti Mohan         20
# Pankaj Udas         20
# Taylor Swift        20
# Drake               20
# Billie Eilish       20
# Justin Bieber       20
# Diljit Dosanjh      20
# Sonu Nigam          20
# A.R. Rahman         20
# B Praak             20
# Darshan Raval       20
# Bruno Mars          20
# Daler Mehndi        20
# Dua Lipa            20
# Imagine Dragons     20
# Olivia Rodrigo      20
# Guru Randhawa       20
# ...

# %%
len(df["Artist"].unique())
# 42*20 = 840 songs.../ 400 hindi/ 440 English
# Out:
# 42

# %%
df.columns
# Out:
# Index(['Artist', 'Country', 'Song', 'url'], dtype='object')

# %%
df.head()
# Out:
#           Artist Country             Song  \
# 0      Lady Gaga     USA       Sour Candy
# 1    Karan Aujla   India       Tere Karke
# 2   Taylor Swift     USA    The Albatross
# 3          Drake     USA   Virginia Beach
# 4  Billie Eilish     USA  Bad Guy (Remix)
#
#                                            url
# 0  https://www.youtube.com/watch?v=fnPn6At3v28
# 1  https://www.youtube.com/watch?v=k85UB5b6pJU
# 2  https://www.youtube.com/watch?v=4wOsiM2T_xc
# 3  https://www.youtube.com/watch?v=k20wnICXpps
# 4  https://www.youtube.com/watch?v=9Wb-oJ6WVy0

# %%
df["Country"].value_counts()
# Out:
# Country
# USA      440
# India    400
# Name: count, dtype: int64

# %%
df_usa = df[df["Country"] == "USA"]
df_usa
# Out:
#             Artist Country                          Song  \
# 0        Lady Gaga     USA                    Sour Candy
# 2     Taylor Swift     USA                 The Albatross
# 3            Drake     USA                Virginia Beach
# 4    Billie Eilish     USA               Bad Guy (Remix)
# 5    Justin Bieber     USA                       Hold On
# ..             ...     ...                           ...
# 828          Drake     USA      Falling Back (2023 Live)
# 830            Sia     USA                         Alive
# 834            Sia     USA                      Together
# 835        Rihanna     USA  What’s My Name? (2024 Remix)
# 837   Taylor Swift     USA                    Florida!!!
#
#                                              url
# 0    https://www.youtube.com/watch?v=fnPn6At3v28
# 2    https://www.youtube.com/watch?v=4wOsiM2T_xc
# 3    https://www.youtube.com/watch?v=k20wnICXpps
# 4    https://www.youtube.com/watch?v=9Wb-oJ6WVy0
# ...

# %%
df_india = df[df["Country"] == "India"].reset_index(drop=True)
df_india
# Out:
#               Artist Country                      Song  \
# 0        Karan Aujla   India                Tere Karke
# 1     Diljit Dosanjh   India               Do you know
# 2         Sonu Nigam   India              Kuch Na Kaho
# 3         Sonu Nigam   India           Yeh Dil Deewana
# 4        A.R. Rahman   India            Chand Sifarish
# ..               ...     ...                       ...
# 395   Jubin Nautiyal   India  Dil Galti Kar Baitha Hai
# 396  Sunidhi Chauhan   India                 Desi Girl
# 397          B Praak   India           Gaddi Jaandi Ae
# 398    Jonita Gandhi   India           Tera Ban Jaunga
# 399      Karan Aujla   India                     Lover
#
#                                              url
# 0    https://www.youtube.com/watch?v=k85UB5b6pJU
# 1    https://www.youtube.com/watch?v=P-DhwN87JDY
# 2    https://www.youtube.com/watch?v=_VywEtukPo0
# 3    https://www.youtube.com/watch?v=_4Ft9UIKzwk
# 4    https://www.youtube.com/watch?v=zWEOx7TSM6I
# ...

# %% [markdown]
# ### Fetch emotion from wiki...

# %%
def load_emotions(filename):
  with open(filename,"r") as file:
    return [line.strip().lower() for line in file if line.strip()]

# %%
import requests
from bs4 import BeautifulSoup
from collections import Counter

def get_top_song_emotions_for_dataset(df, emotion_keywords):
    """
    This function fetches a minimum of 1 and a maximum of 2 emotions per song based on keywords
    found in the song's Wikipedia page. If less than 1 emotion is found, it will fill with 'NO EMOTION'.
    If the page is not found, 'Page not found' will be set.
    """
    for index, row in df.iterrows():
        song_name = row['Song']  # Assumes there is a 'Song' column
        query = song_name.replace(" ", "_")
        url = f"https://en.wikipedia.org/wiki/{query}"

        response = requests.get(url)

        if response.status_code == 200:
            soup = BeautifulSoup(response.content, "html.parser")
            paragraphs = soup.find_all("p")

            # Counter to store detected emotions and their frequency
            emotion_counter = Counter()

            # Process each paragraph to detect emotions
            for paragraph in paragraphs:
                text = paragraph.get_text().lower()  # Convert text to lowercase
                for keyword in emotion_keywords:
                    if keyword in text:
                        emotion_counter[keyword.capitalize()] += 1  # Count occurrences of each emotion

            # Select the top 2 emotions based on frequency (if available)
            top_emotions = [emotion for emotion, count in emotion_counter.most_common(2)]

            # Handle the case where no emotions were found
            if len(top_emotions) == 0:
                df.at[index, 'Emotion'] = "NO EMOTION"
            else:
                # If there's only one emotion, leave it as it is, else join top 2
                df.at[index, 'Emotion'] = ', '.join(top_emotions)
        else:
            # In case the Wikipedia page is not found
            df.at[index, 'Emotion'] = "Page not found"

    return df

# %%
def count_emotions_per_line(filename):
  emotion_set =()
  with open(filename,"r") as file:
    for line in file:
      emotion = line.strip().lower()
      if emotion:
        emotion_set.add(emotion)
  return len(emotion_set)

# %%
len(df_usa),df_usa.columns
# Out:
# (440, Index(['Artist', 'Country', 'Song', 'url'], dtype='object'))

# %%
emotion_txt_file = load_emotions("/content/song_emotion.txt")

# %%
df_india["Emotion"] = ""
df_india = get_top_song_emotions_for_dataset(df_india,emotion_txt_file)

# %%
df_usa["Emotion"] = ""
df_usa = get_top_song_emotions_for_dataset(df_usa,emotion_txt_file)
# Out:
# <ipython-input-38-6fc78554556e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usa["Emotion"] = ""

# %%
df_usa.columns
# Out:
# Index(['Artist', 'Country', 'Song', 'url', 'Emotion'], dtype='object')

# %% [markdown]
# ### INDIA

# %%
df_india[df_india["Emotion"] != "Page not found."]
# Out:
#               Artist Country                      Song  \
# 0        Karan Aujla   India                Tere Karke
# 1     Diljit Dosanjh   India               Do you know
# 2         Sonu Nigam   India              Kuch Na Kaho
# 3         Sonu Nigam   India           Yeh Dil Deewana
# 4        A.R. Rahman   India            Chand Sifarish
# ..               ...     ...                       ...
# 395   Jubin Nautiyal   India  Dil Galti Kar Baitha Hai
# 396  Sunidhi Chauhan   India                 Desi Girl
# 397          B Praak   India           Gaddi Jaandi Ae
# 398    Jonita Gandhi   India           Tera Ban Jaunga
# 399      Karan Aujla   India                     Lover
#
#                                              url          Emotion
# 0    https://www.youtube.com/watch?v=k85UB5b6pJU   Page not found
# 1    https://www.youtube.com/watch?v=P-DhwN87JDY       NO EMOTION
# 2    https://www.youtube.com/watch?v=_VywEtukPo0   Love, Spirited
# ...

# %%
df_india.isna().sum()
#so no nan values
# Out:
# Artist     0
# Country    0
# Song       0
# url        0
# Emotion    0
# dtype: int64

# %%
len(df_india),df_india.columns
# Out:
# (400, Index(['Artist', 'Country', 'Song', 'url', 'Emotion'], dtype='object'))

# %%
df_india[df_india["Emotion"] == "NO EMOTION"].shape[0]
# 44 entries are having no emotions...
# Out:
# 44

# %%
df_india["Emotion"].value_counts()
# Out:
# Emotion
# Page not found           201
# NO EMOTION                44
# Love, Success             12
# Love, Elation             10
# Love, Pop                  9
#                         ...
# Disappointment, Disco      1
# Pop, Soul                  1
# Love, Happiness            1
# Pop, Unity                 1
# Fear, Faith                1
# Name: count, Length: 73, dtype: int64

# %%
#lets check for NO EMotion values...
#df[(df["Emotion"] == "NO EMOTION") & (df["Country"]=="USA")].shape[0]

# %%
df_india[df_india["Emotion"] == "NO EMOTION"]
# Out:
#               Artist Country                            Song  \
# 1     Diljit Dosanjh   India                     Do you know
# 18   Sunidhi Chauhan   India                             Udi
# 38    Jubin Nautiyal   India                            Raaz
# 50     Jonita Gandhi   India                         Baarish
# 56       A.R. Rahman   India                       Dil Se Re
# 58   Sunidhi Chauhan   India                       Dil Se Re
# 63       Pankaj Udas   India  Chura Liya Hai Tumne Jo Dil Ko
# 65     Vishal Mishra   India                             Pal
# 71    Shreya Ghoshal   India                       Tere Bina
# 81      Arijit Singh   India                            Hasi
# 82    Sachin Sanghvi   India                          Kabira
# 94           B Praak   India                           Jaanu
# 97      Arijit Singh   India                             Pal
# 98      Arijit Singh   India                          Kabira
# ...

# %% [markdown]
# ```
# So out of 158 songs which have no emotion 114 are ENGLISH songs..
#
# and 44 songs will be from HINDI music..
#
# ```

# %%
#df[(df["Emotion"] == "NO EMOTION") & (df["Country"]=="India")].shape[0]
## 44

# %%
df_india[df_india["Emotion"] == "Page not found"]
# Out:
#                Artist Country                      Song  \
# 0         Karan Aujla   India                Tere Karke
# 3          Sonu Nigam   India           Yeh Dil Deewana
# 6       Darshan Raval   India             Hasi Ban Gaye
# 7         Karan Aujla   India    Dilli Waali Girlfriend
# 9      Diljit Dosanjh   India         Sauda Khara Khara
# ..                ...     ...                       ...
# 391     Darshan Raval   India             Jaan Ban Gaye
# 392      Armaan Malik   India     Kisi Se Pyaar Ho Jaye
# 393  Sukhwinder Singh   India    Chal Chhaiyya Chhaiyya
# 395    Jubin Nautiyal   India  Dil Galti Kar Baitha Hai
# 397           B Praak   India           Gaddi Jaandi Ae
#
#                                              url         Emotion
# 0    https://www.youtube.com/watch?v=k85UB5b6pJU  Page not found
# 3    https://www.youtube.com/watch?v=_4Ft9UIKzwk  Page not found
# 6    https://www.youtube.com/watch?v=8Zhp6f8fD2w  Page not found
# ...

# %%
df_india[df_india["Emotion"] == "Page not found"].shape[0] #201
# Out:
# 201

# %%
##df[(df["Emotion"] == "NO EMOTION") & (df["Country"]=="India")].shape[0]
df_problem1_ind = df_india[df_india["Emotion"] == "NO EMOTION"]
df_problem1_ind.reset_index(drop=True)
df_problem1_ind.drop(["Emotion"],axis=1,inplace=True)

len(df_problem1_ind) # 44
# Out:
# <ipython-input-50-6bb174689ae7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_problem1_ind.drop(["Emotion"],axis=1,inplace=True)
# 44

# %%
df_problem1_ind.head()
# Out:
#              Artist Country         Song  \
# 1    Diljit Dosanjh   India  Do you know
# 18  Sunidhi Chauhan   India          Udi
# 38   Jubin Nautiyal   India         Raaz
# 50    Jonita Gandhi   India      Baarish
# 56      A.R. Rahman   India    Dil Se Re
#
#                                             url
# 1   https://www.youtube.com/watch?v=P-DhwN87JDY
# 18  https://www.youtube.com/watch?v=hbP3vLetsnM
# 38  https://www.youtube.com/watch?v=2ZFVYBkCoSY
# 50  https://www.youtube.com/watch?v=YcBH4ZInBvY
# 56  https://www.youtube.com/watch?v=U3hZW62-KGA

# %%
df_problem2_ind = df_india[df_india["Emotion"] == "Page not found"]
df_problem2_ind.reset_index(drop=True)
df_problem2_ind.drop(["Emotion"],inplace=True,axis=1)
len(df_problem2_ind) # 201
# Out:
# <ipython-input-52-4333c8d7ed55>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_problem2_ind.drop(["Emotion"],inplace=True,axis=1)
# 201

# %%
df_problem2_ind.head()
# Out:
#            Artist Country                    Song  \
# 0     Karan Aujla   India              Tere Karke
# 3      Sonu Nigam   India         Yeh Dil Deewana
# 6   Darshan Raval   India           Hasi Ban Gaye
# 7     Karan Aujla   India  Dilli Waali Girlfriend
# 9  Diljit Dosanjh   India       Sauda Khara Khara
#
#                                            url
# 0  https://www.youtube.com/watch?v=k85UB5b6pJU
# 3  https://www.youtube.com/watch?v=_4Ft9UIKzwk
# 6  https://www.youtube.com/watch?v=8Zhp6f8fD2w
# 7  https://www.youtube.com/watch?v=dgAlcaIv-7Q
# 9  https://www.youtube.com/watch?v=LYEqeUr-158

# %%
#lets merge them to combine them 201 + 44 =  245 entries
df_problem_ind = pd.concat([df_problem1_ind,df_problem2_ind], ignore_index=True)
len(df_problem_ind) #245
# Out:
# 245

# %%
df_problem_ind.head()
# Out:
#             Artist Country         Song  \
# 0   Diljit Dosanjh   India  Do you know
# 1  Sunidhi Chauhan   India          Udi
# 2   Jubin Nautiyal   India         Raaz
# 3    Jonita Gandhi   India      Baarish
# 4      A.R. Rahman   India    Dil Se Re
#
#                                            url
# 0  https://www.youtube.com/watch?v=P-DhwN87JDY
# 1  https://www.youtube.com/watch?v=hbP3vLetsnM
# 2  https://www.youtube.com/watch?v=2ZFVYBkCoSY
# 3  https://www.youtube.com/watch?v=YcBH4ZInBvY
# 4  https://www.youtube.com/watch?v=U3hZW62-KGA

# %%
#let see which which artists are mostly present in the problem dataset....
df_problem_ind["Artist"].value_counts(), df_problem_ind["Artist"].value_counts().sum()
# Out:
# (Artist
#  Armaan Malik        17
#  Jubin Nautiyal      17
#  Neeti Mohan         14
#  Darshan Raval       14
#  Daler Mehndi        14
#  Diljit Dosanjh      14
#  Vishal Mishra       13
#  Sachin Sanghvi      13
#  Sunidhi Chauhan     13
#  B Praak             12
#  Karan Aujla         11
#  A.R. Rahman         11
#  Guru Randhawa       11
#  Sonu Nigam          11
#  Jonita Gandhi       11
#  Atif Aslam          11
#  Sukhwinder Singh    11
#  Shreya Ghoshal      10
#  Pankaj Udas         10
#  Arijit Singh         7
#  Name: count, dtype: int64,
#  245)

# %% [markdown]
# ```
# (Artist
#  Jubin Nautiyal      17
#  Armaan Malik        17
#  Daler Mehndi        14
#  Darshan Raval       14
#  Diljit Dosanjh      14
#  Neeti Mohan         14
#  Vishal Mishra       13
#  Sunidhi Chauhan     13
#  Sachin Sanghvi      13
#  B Praak             12
#  Atif Aslam          11
#  Sonu Nigam          11
#  Sukhwinder Singh    11
#  Karan Aujla         11
#  A.R. Rahman         11
#  Jonita Gandhi       11
#  Guru Randhawa       11
#  Shreya Ghoshal      10
#  Pankaj Udas         10
#  Arijit Singh         7
# )
# ```

# %% [markdown]
# ```
# So each artists in the Hindi song has 20 songs but we can witness 245 out of 400 have wither no emotions been fetched from internet or PAGE is not been
# found and we can easily see those artists above....
#
# So we will be some emotions from our end manually considering the artists style
# and way of singing ....
# ```

# %%
artist_emotions = {
"Arijit_Singh" : ["Love","Heartbreak","Longing","Melancholy","Passion","Nostalgia","Hope","Loneliness","Betrayal","Sorrow","Regret","Forgiveness","Healing","Admiration","Devotion","Comfort","Yearning for freedom","Confusion","Strength","Joy","Desperation","Faithfulness","Resignation","Bitterness","Bittersweetness"],

"A.R._Rahman" : ["Wonder","Passion","Gratitude","Adventure","Resilience","Melancholy","Patriotism","Peace","Hope","Transcendence","Inspiration"],

"Jubin_Nautiyal" : ["Love", "Heartache","Longing","Hope","Sadness","Nostalgia","Passion","Faithfulness","Desperation","Melancholy","Healing","Joy","Resilience","Bitterness","Admiration","Solitude","Acceptance","Tenderness","Mystery","Comfort","Gratitude","Dreaminess","Vulnerability","Forgiveness","Spirituality"],

"B_Praak" : ["Devotion","Regret","Pain","Love","Melancholy","Heartbreak","Resilience","Desperation","Solitude","Acceptance","Nostalgia","Hope","Tenderness","Strength","Vulnerability"],

"Darshan_Raval": ["Love","Heartbreak","Longing","Joy","Nostalgia","Melancholy","Admiration","Passion","Bittersweetness","Resilience","Solitude","Hope","Innocence","Forgiveness","Vulnerability","Comfort","Faithfulness","Confusion","Healing","Dreaminess","Desperation","Acceptance","Tenderness","Admiration for nature","Spirituality"],

"Sukhwinder_Singh": ["Patriotism","Courage","Resilience","Determination","Exuberance","Devotion","Spirituality","Melancholy","Passion","Strength","Sacrifice","Mysticism","Perseverance","Faith"],

"Neeti_Mohan" : ["Love","Joy","Confidence","Passion","Heartbreak","Playfulness","Nostalgia","Longing","Strength","Admiration","Tenderness","Melancholy","Excitement","Gratitude","Playful Romance","Resilience","Faithfulness","Bittersweetness","Celebration","Dreaminess"],

"Daler_Mehndi" : ["Exuberance","Festivity","Pride","Love","Unity","Nostalgia","Energy","Loyalty","Energy","Strength","Freedom","Spontaneity","Contentment"],

"Shreya_Ghoshal" :["Love","Heartbreak","Longing","Tenderness","Hope","Bittersweetness","Innocence","Vulnerability","Comfort","Elegance","Regret","Serenity","Grief"],

"Karan_Aujla" : ["Pride","Rap","Confidence","Loyalty","Ambition","Power","Reflection","Aspiration","Celebration","Friendship","Hard Work","Fearlessness","Individuality","Punjabi","Friendship","Celebration","Mystery"],
"Sonu_Nigam" : ["Love","Romance","Peace","Gratitude","Wisdom","Joy","Celebration","Sorrow","Acceptance","Reflection","Optimism","Simplicity","Elegance"],
"Armaan_Malik": ["Romance","Hope","Self-Reflection","Sorrow","Yearning","Happiness","Hope","Excitment","Affection","Euphoria","Healing"],
"Jonita_Gandhi" : ["Empowerment","Affection","Playfulness","Yearning","Admiration","Affection","Romantic Idealism","Tenderness","Excitement","Compassion","Adoration","Strength","Power"],
"Pankaj_Udas" : ["Longing","Heartbreak","Melancholy","Nostalgia","Solitude","Resilience","Admiration","Acceptance","Regret","Hope","Forgiveness","Sorrow","Yearning for Peace","Devotion","Gratitude"],
"Guru_Randhawa" : ["Confidence","Fun","Pride","Ambition","Flirtation","Vibrancy","Self-Love","Loyalty","Romance","Satisfaction","Happiness","Desire","Defiance"],
"Sachin_Sanghvi" : ["Romance","Sorrow","Devotion","Hope","Self-discovery","Determination","Tenderness","Adoration"],
"Diljit_Dosanjh" : ["Celebration","Longing","Passion","Inspiration","Devotion","Punjabi","Pride","Admiration","Compassion","Love","Nostalgia","Adventure"],

"Atif_Aslam" : ["Melancholy","Gratitude","Introspection","Sadness","Reconciliation","Trust","Comfort","Passion","Faith","Solitude"],
"Sunidhi_Chauhan" : ["Playfulness","Empowerment","Passion","Confidence","Hope","Excitement","Determination","Reflection","Intensity"],
"Vishal_Mishra" : ["Melancholy","Introspection","Yearning","Longing","Sorrow","Gratitude","Euphoria","Vulnerability","Vibrancy","Trust","Compassion","Empathy"],

}

# %%
def lets_format_artist_name(artist_name):
  return artist_name.replace(" ","_")

# %%
import random

# Function to assign 2 random emotions to a song based on the artist
def assign_emotions(artist):
    #random.seed(seed)  # Ensure reproducibility for the random choices

    # Format artist name and fetch the emotions list
    formatted_artist = lets_format_artist_name(artist)  # Format artist name
    emotions = artist_emotions.get(formatted_artist, [])

    if len(emotions) == 0:
        return 'No emotion'  # If no emotions are found for the artist, return 'No emotion'

    # If there are fewer than 2 emotions, repeat them to ensure 2 emotions are available
    if len(emotions) < 2:
        emotions = emotions * 2  # Repeat the emotions to fill up the list

    # Randomly select 2 emotions for this song from the available emotions
    return ', '.join(random.sample(emotions, 2))  # Randomly select 2 emotions and return as a string

# %%
df_problem_ind.columns, df_problem_ind.isna().sum()
# Out:
# (Index(['Artist', 'Country', 'Song', 'url'], dtype='object'),
#  Artist     0
#  Country    0
#  Song       0
#  url        0
#  dtype: int64)

# %%
df_problem_ind["Emotion"] = df_problem_ind["Artist"].apply(lambda x: assign_emotions(x))

# %%
df_problem_ind
# Out:
#                Artist Country                      Song  \
# 0      Diljit Dosanjh   India               Do you know
# 1     Sunidhi Chauhan   India                       Udi
# 2      Jubin Nautiyal   India                      Raaz
# 3       Jonita Gandhi   India                   Baarish
# 4         A.R. Rahman   India                 Dil Se Re
# ..                ...     ...                       ...
# 240     Darshan Raval   India             Jaan Ban Gaye
# 241      Armaan Malik   India     Kisi Se Pyaar Ho Jaye
# 242  Sukhwinder Singh   India    Chal Chhaiyya Chhaiyya
# 243    Jubin Nautiyal   India  Dil Galti Kar Baitha Hai
# 244           B Praak   India           Gaddi Jaandi Ae
#
#                                              url                       Emotion
# 0    https://www.youtube.com/watch?v=P-DhwN87JDY        Adventure, Celebration
# 1    https://www.youtube.com/watch?v=hbP3vLetsnM          Passion, Empowerment
# ...

# %%
df_problem_ind[df_problem_ind["Artist"] == "A.R. Rahman"]
# Out:
#           Artist Country                  Song  \
# 4    A.R. Rahman   India             Dil Se Re
# 29   A.R. Rahman   India             Tere Bina
# 30   A.R. Rahman   India      Maa Tujhe Salaam
# 70   A.R. Rahman   India    O Humdum Suniyo Re
# 81   A.R. Rahman   India     Taal Se Taal Mila
# 96   A.R. Rahman   India         Roja Jaaneman
# 136  A.R. Rahman   India          Kehna Hi Kya
# 154  A.R. Rahman   India  Khwaabon Ke Parindey
# 157  A.R. Rahman   India        Mann Ki Manzil
# 192  A.R. Rahman   India     Taal Se Taal Mila
# 229  A.R. Rahman   India          Kun Faya Kun
#
#                                              url                     Emotion
# 4    https://www.youtube.com/watch?v=U3hZW62-KGA        Peace, Transcendence
# 29   https://www.youtube.com/watch?v=9JDSGhhiOwI         Patriotism, Passion
# 30   https://www.youtube.com/watch?v=jDn2bn7_YSM       Melancholy, Adventure
# 70   https://www.youtube.com/watch?v=_9geEbZIAJM      Patriotism, Resilience
# ...

# %%
df_problem_ind[df_problem_ind["Artist"] == "Diljit Dosanjh"]
# Out:
#              Artist Country               Song  \
# 0    Diljit Dosanjh   India        Do you know
# 27   Diljit Dosanjh   India              Shada
# 33   Diljit Dosanjh   India               Pyar
# 34   Diljit Dosanjh   India        Do you know
# 38   Diljit Dosanjh   India      Proper Patola
# 41   Diljit Dosanjh   India            Goliyan
# 48   Diljit Dosanjh   India  Sauda Khara Khara
# 100  Diljit Dosanjh   India       Chal Jindadi
# 102  Diljit Dosanjh   India            Ik Saal
# 104  Diljit Dosanjh   India   Gaddi Jaandi Hai
# 117  Diljit Dosanjh   India        Laembadgini
# 134  Diljit Dosanjh   India        Sooha Sooti
# 147  Diljit Dosanjh   India       Sohne Mukhde
# 161  Diljit Dosanjh   India         Dabda Kutt
#
#                                              url                  Emotion
# 0    https://www.youtube.com/watch?v=P-DhwN87JDY   Adventure, Celebration
# 27   https://www.youtube.com/watch?v=RgafWFZdIAM      Compassion, Passion
# ...

# %%
df_problem_ind[df_problem_ind["Song"] == "Kun Faya Kun"]
# Out:
#           Artist Country          Song  \
# 229  A.R. Rahman   India  Kun Faya Kun
#
#                                              url               Emotion
# 229  https://www.youtube.com/watch?v=T94PHkuydcw  Transcendence, Peace

# %%
df_problem_ind.isna().sum()
# Out:
# Artist     0
# Country    0
# Song       0
# url        0
# Emotion    0
# dtype: int64

# %%
df_problem_ind["Emotion"].value_counts().sum() #should be 245
# Out:
# 245

# %%
df_problem_ind["Emotion"].value_counts()
# Out:
# Emotion
# Longing, Melancholy         3
# Patriotism, Spirituality    2
# Admiration, Longing         2
# Sorrow, Forgiveness         2
# Romance, Sorrow             2
#                            ..
# Loyalty, Ambition           1
# Heartbreak, Innocence       1
# Playfulness, Yearning       1
# Euphoria, Yearning          1
# Regret, Heartbreak          1
# Name: count, Length: 225, dtype: int64

# %%
len(df_india)
# Out:
# 400

# %%
df_india[df_india["Emotion"] == "Page not found"].shape[0]
# Out:
# 201

# %%
df_india_1 = df_india[df_india["Emotion"] != "Page not found"]
df_india_2 = df_india_1[df_india_1["Emotion"] != "NO EMOTION"]

# %%
len(df_india_2)
# Out:
# 155

# %%
len(df_india_2)  # 199 - 44 =
# Out:
# 155

# %%
len(df_india_1) # 400-201 =
# Out:
# 199

# %%
df_india_2
# Out:
#               Artist Country                     Song  \
# 2         Sonu Nigam   India             Kuch Na Kaho
# 4        A.R. Rahman   India           Chand Sifarish
# 5            B Praak   India                   Qareeb
# 8       Daler Mehndi   India          Tunak Tunak Tun
# 12       Pankaj Udas   India          Rang De Basanti
# ..               ...     ...                      ...
# 388   Shreya Ghoshal   India  Tujhe Kitna Chahne Lage
# 390  Sunidhi Chauhan   India              Aaja Nachle
# 394      A.R. Rahman   India                   Zubaan
# 398    Jonita Gandhi   India          Tera Ban Jaunga
# 399      Karan Aujla   India                    Lover
#
#                                              url           Emotion
# 2    https://www.youtube.com/watch?v=_VywEtukPo0    Love, Spirited
# 4    https://www.youtube.com/watch?v=zWEOx7TSM6I   Country, Melody
# 5    https://www.youtube.com/watch?v=44BHGfFGHTg         Jazz, Pop
# ...

# %%
df_india_2["Emotion"].value_counts().sum()
# Out:
# 155

# %%
df_india_2["Emotion"].value_counts()
# Out:
# Emotion
# Love, Success            12
# Love, Elation            10
# Love, Pop                 9
# Love, Longing             7
# Love, House               6
#                          ..
# Disappointment, Disco     1
# Pop, Soul                 1
# Love, Happiness           1
# Pop, Unity                1
# Fear, Faith               1
# Name: count, Length: 71, dtype: int64

# %%
len(df_problem_ind), len(df_india_2), len(df_problem_ind) + len(df_india_2)
# Out:
# (245, 155, 400)

# %%
df_india_final = pd.concat([df_india_2,df_problem_ind],ignore_index=True)
len(df_india_final)
# Out:
# 400

# %%
df_india_final
# Out:
#                Artist Country                      Song  \
# 0          Sonu Nigam   India              Kuch Na Kaho
# 1         A.R. Rahman   India            Chand Sifarish
# 2             B Praak   India                    Qareeb
# 3        Daler Mehndi   India           Tunak Tunak Tun
# 4         Pankaj Udas   India           Rang De Basanti
# ..                ...     ...                       ...
# 395     Darshan Raval   India             Jaan Ban Gaye
# 396      Armaan Malik   India     Kisi Se Pyaar Ho Jaye
# 397  Sukhwinder Singh   India    Chal Chhaiyya Chhaiyya
# 398    Jubin Nautiyal   India  Dil Galti Kar Baitha Hai
# 399           B Praak   India           Gaddi Jaandi Ae
#
#                                              url                   Emotion
# 0    https://www.youtube.com/watch?v=_VywEtukPo0            Love, Spirited
# 1    https://www.youtube.com/watch?v=zWEOx7TSM6I           Country, Melody
# ...

# %%
df_india_final[df_india_final["Song"]=="Kun Faya Kun"]
# Out:
#           Artist Country          Song  \
# 384  A.R. Rahman   India  Kun Faya Kun
#
#                                              url               Emotion
# 384  https://www.youtube.com/watch?v=T94PHkuydcw  Transcendence, Peace

# %%
df_india_final["Emotion"].value_counts()
# Out:
# Emotion
# Love, Success              12
# Love, Elation              10
# Love, Pop                   9
# Love, Longing               7
# Love, House                 6
#                            ..
# Vulnerability, Euphoria     1
# Determination, Faith        1
# Gratitude, Reflection       1
# Friendship, Pride           1
# Regret, Heartbreak          1
# Name: count, Length: 295, dtype: int64

# %%
df_india_final.isna().sum()
# Out:
# Artist     0
# Country    0
# Song       0
# url        0
# Emotion    0
# dtype: int64

# %% [markdown]
# ### USA

# %%
df_usa
# Out:
#             Artist Country                          Song  \
# 0        Lady Gaga     USA                    Sour Candy
# 2     Taylor Swift     USA                 The Albatross
# 3            Drake     USA                Virginia Beach
# 4    Billie Eilish     USA               Bad Guy (Remix)
# 5    Justin Bieber     USA                       Hold On
# ..             ...     ...                           ...
# 828          Drake     USA      Falling Back (2023 Live)
# 830            Sia     USA                         Alive
# 834            Sia     USA                      Together
# 835        Rihanna     USA  What’s My Name? (2024 Remix)
# 837   Taylor Swift     USA                    Florida!!!
#
#                                              url         Emotion
# 0    https://www.youtube.com/watch?v=fnPn6At3v28      NO EMOTION
# 2    https://www.youtube.com/watch?v=4wOsiM2T_xc      NO EMOTION
# 3    https://www.youtube.com/watch?v=k20wnICXpps       Folk, Pop
# ...

# %%
df_usa[df_usa["Emotion"] == "NO EMOTION"]
# 114
# Out:
#             Artist Country              Song  \
# 0        Lady Gaga     USA        Sour Candy
# 2     Taylor Swift     USA     The Albatross
# 5    Justin Bieber     USA           Hold On
# 17        Dua Lipa     USA        Be the One
# 23         Beyoncé     USA            Heated
# ..             ...     ...               ...
# 803       Coldplay     USA     Everyday Life
# 805   Shawn Mendes     USA          Senorita
# 809       Dua Lipa     USA  Kiss and Make Up
# 830            Sia     USA             Alive
# 834            Sia     USA          Together
#
#                                              url     Emotion
# 0    https://www.youtube.com/watch?v=fnPn6At3v28  NO EMOTION
# 2    https://www.youtube.com/watch?v=4wOsiM2T_xc  NO EMOTION
# 5    https://www.youtube.com/watch?v=LWeiydKl0mU  NO EMOTION
# 17   https://www.youtube.com/watch?v=-rey3m8SWQI  NO EMOTION
# 23   https://www.youtube.com/watch?v=o3WqRPM6M0A  NO EMOTION
# ...

# %%
df_usa[df_usa["Emotion"] == "NO EMOTION"].shape[0]
# Out:
# 114

# %%
df_usa[df_usa["Emotion"] == "Page not found"].shape[0]
# Out:
# 117

# %%
len(df_problem1_ind), len(df_problem2_ind)
# Out:
# (44, 201)

# %%
# 440 - 114 = 326
# 326 - 117 = 209
df_problem1_usa = df_usa[df_usa["Emotion"] == "NO EMOTION"]
df_problem1_usa.drop(["Emotion"],inplace=True,axis=1)
df_problem1_usa.reset_index(drop=True)
len(df_problem1_usa)
# Out:
# <ipython-input-89-408bcd086aaa>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_problem1_usa.drop(["Emotion"],inplace=True,axis=1)
# 114

# %%
df_problem2_usa = df_usa[df_usa["Emotion"] == "Page not found"]
df_problem2_usa.drop(["Emotion"],inplace=True,axis=1)
df_problem2_usa.reset_index(drop=True)
len(df_problem2_usa)
# Out:
# <ipython-input-90-ddafc1e5f3e1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_problem2_usa.drop(["Emotion"],inplace=True,axis=1)
# 117

# %%
df_problem2_usa.columns
# Out:
# Index(['Artist', 'Country', 'Song', 'url'], dtype='object')

# %%
df_problem1_usa.columns
# Out:
# Index(['Artist', 'Country', 'Song', 'url'], dtype='object')

# %%
df_problem1_usa.head()
# Out:
#            Artist Country           Song  \
# 0       Lady Gaga     USA     Sour Candy
# 2    Taylor Swift     USA  The Albatross
# 5   Justin Bieber     USA        Hold On
# 17       Dua Lipa     USA     Be the One
# 23        Beyoncé     USA         Heated
#
#                                             url
# 0   https://www.youtube.com/watch?v=fnPn6At3v28
# 2   https://www.youtube.com/watch?v=4wOsiM2T_xc
# 5   https://www.youtube.com/watch?v=LWeiydKl0mU
# 17  https://www.youtube.com/watch?v=-rey3m8SWQI
# 23  https://www.youtube.com/watch?v=o3WqRPM6M0A

# %%
df_problem2_usa.head()
# Out:
#            Artist Country                              Song  \
# 22  Billie Eilish     USA                Lovely (2024 Live)
# 30     Bruno Mars     USA      Somebody Else (2024 Version)
# 37    Post Malone     USA             Sunflower (2024 Live)
# 41        Rihanna     USA  Love on the Brain (2024 Version)
# 58          Drake     USA           Trophies (2023 Version)
#
#                                             url
# 22  https://www.youtube.com/watch?v=OBJ8JALSEXk
# 30  https://www.youtube.com/watch?v=w2gUOKTaKH4
# 37  https://www.youtube.com/watch?v=M3M1i6ivkug
# 41  https://www.youtube.com/watch?v=0RyInjfgNc4
# 58  https://www.youtube.com/watch?v=IIOMdpWfxlk

# %%
df_problem1_usa["Artist"].value_counts()
# Out:
# Artist
# Ed Sheeran         11
# Sia                11
# The Weeknd         10
# Dua Lipa            9
# Imagine Dragons     9
# Lady Gaga           8
# Demi Lovato         7
# Beyoncé             6
# Justin Bieber       6
# Drake               5
# Shawn Mendes        5
# Coldplay            5
# Post Malone         4
# Taylor Swift        4
# Olivia Rodrigo      4
# Katy Perry          3
# Nicki Minaj         3
# Eminem              1
# Rihanna             1
# Bruno Mars          1
# Billie Eilish       1
# Name: count, dtype: int64

# %%
df_problem2_usa["Artist"].value_counts()
# Out:
# Artist
# Rihanna           19
# Bruno Mars        17
# Eminem            17
# Ariana Grande     16
# Billie Eilish     13
# Drake             11
# Post Malone        5
# Justin Bieber      5
# Shawn Mendes       4
# Olivia Rodrigo     3
# Taylor Swift       2
# The Weeknd         1
# Beyoncé            1
# Lady Gaga          1
# Katy Perry         1
# Sia                1
# Name: count, dtype: int64

# %%
df_problem_usa = pd.concat([df_problem1_usa,df_problem2_usa],ignore_index=True)
len(df_problem_usa)
# Out:
# 231

# %%
df_problem_usa
# Out:
#             Artist Country                          Song  \
# 0        Lady Gaga     USA                    Sour Candy
# 1     Taylor Swift     USA                 The Albatross
# 2    Justin Bieber     USA                       Hold On
# 3         Dua Lipa     USA                    Be the One
# 4          Beyoncé     USA                        Heated
# ..             ...     ...                           ...
# 226          Drake     USA                       Lurkin’
# 227  Ariana Grande     USA         Sweetener (2024 Live)
# 228         Eminem     USA    Rap God (Extended Version)
# 229          Drake     USA      Falling Back (2023 Live)
# 230        Rihanna     USA  What’s My Name? (2024 Remix)
#
#                                              url
# 0    https://www.youtube.com/watch?v=fnPn6At3v28
# 1    https://www.youtube.com/watch?v=4wOsiM2T_xc
# 2    https://www.youtube.com/watch?v=LWeiydKl0mU
# 3    https://www.youtube.com/watch?v=-rey3m8SWQI
# ...

# %%
df_problem_usa["Artist"].value_counts()
# Out:
# Artist
# Rihanna            20
# Bruno Mars         18
# Eminem             18
# Ariana Grande      16
# Drake              16
# Billie Eilish      14
# Sia                12
# Justin Bieber      11
# The Weeknd         11
# Ed Sheeran         11
# Shawn Mendes        9
# Lady Gaga           9
# Post Malone         9
# Imagine Dragons     9
# Dua Lipa            9
# Olivia Rodrigo      7
# Beyoncé             7
# Demi Lovato         7
# Taylor Swift        6
# Coldplay            5
# Katy Perry          4
# Nicki Minaj         3
# Name: count, dtype: int64

# %%
artist_emotions_usa = {
    "Rihanna": ["Confidence", "Empowerment", "Love", "Independence", "Heartbreak", "Resilience", "Anger", "Passion", "Fearlessness", "Revenge", "Defiance", "Strength", "Vulnerability", "Regret", "Desire", "Hope", "Euphoria", "Longing", "Rebellion", "Celebration"],

    "Eminem": ["Anger", "Frustration", "Self-Reflection", "Vulnerability", "Confidence", "Pain", "Defiance", "Loneliness", "Regret", "Hope", "Revenge", "Empowerment", "Fear", "Struggle", "Resilience", "Obsession", "Determination", "Grief", "Sarcasm"],

    "Bruno_Mars": ["Romance", "Joy", "Celebration", "Playfulness", "Heartbreak", "Nostalgia", "Gratitude", "Passion", "Confidence", "Love", "Tenderness", "Excitement", "Desire", "Empowerment", "Adventure", "Satisfaction", "Fun", "Spontaneity"],

    "Ariana_Grande": ["Love", "Hope", "Empowerment", "Heartbreak", "Passion", "Strength", "Loneliness", "Romance", "Yearning", "Confidence", "Joy", "Desire", "Introspection", "Vulnerability", "Inspiration", "Celebration", "Healing", "Gratitude"],

    "Drake": ["Heartbreak", "Loneliness", "Confidence", "Reflection", "Nostalgia", "Love", "Vulnerability", "Desperation", "Ambition", "Empowerment", "Regret", "Hope", "Self-Reflection", "Pain", "Revenge", "Desire", "Romance", "Strength"],

    "Billie_Eilish": ["Sadness", "Loneliness", "Empowerment", "Darkness", "Vulnerability", "Fear", "Angst", "Desperation", "Self-Reflection", "Hope", "Confusion", "Isolation", "Regret", "Introspection", "Rebellion", "Melancholy", "Grief", "Mystery"],

    "Sia": ["Empowerment", "Strength", "Loneliness", "Anger", "Hope", "Resilience", "Heartbreak", "Joy", "Confidence", "Self-Reflection", "Healing", "Fear", "Yearning", "Desperation", "Rejection", "Independence", "Passion", "Courage"],

    "Ed_Sheeran": ["Love", "Heartbreak", "Romance", "Nostalgia", "Hope", "Desire", "Regret", "Vulnerability", "Joy", "Celebration", "Loneliness", "Gratitude", "Tenderness", "Yearning", "Inspiration", "Reflection", "Healing"],

    "Justin_Bieber": ["Love", "Heartbreak", "Faith", "Hope", "Desire", "Regret", "Vulnerability", "Joy", "Reflection", "Peace", "Healing", "Romance", "Faithfulness", "Empowerment", "Excitement", "Playfulness", "Resilience"],

    "The_Weeknd": ["Love", "Heartbreak", "Regret", "Loneliness", "Desire", "Nostalgia", "Addiction", "Rebellion", "Fear", "Anger", "Vulnerability", "Introspection", "Passion", "Hope", "Confidence", "Euphoria", "Empowerment"],

    "Post_Malone": ["Heartbreak", "Loneliness", "Desperation", "Confidence", "Vulnerability", "Regret", "Romance", "Sadness", "Reflection", "Ambition", "Resilience", "Isolation", "Hope", "Nostalgia", "Introspection", "Resignation", "Strength"],

    "Shawn_Mendes": ["Love", "Heartbreak", "Longing", "Hope", "Passion", "Desire", "Nostalgia", "Reflection", "Vulnerability", "Healing", "Confidence", "Yearning", "Fear", "Romance", "Regret", "Strength", "Excitement"],

    "Lady_Gaga": ["Confidence", "Empowerment", "Rebellion", "Love", "Loneliness", "Heartbreak", "Strength", "Desire", "Vulnerability", "Self-Expression", "Anger", "Hope", "Passion", "Introspection", "Nostalgia", "Revenge", "Mystery"],

    "Dua_Lipa": ["Confidence", "Empowerment", "Freedom", "Romance", "Heartbreak", "Independence", "Desire", "Resilience", "Joy", "Fun", "Celebration", "Nostalgia", "Passion", "Strength", "Rebellion", "Excitement", "Fearlessness"],

    "Imagine_Dragons": ["Hope", "Empowerment", "Strength", "Resilience", "Anger", "Confidence", "Desperation", "Fear", "Loneliness", "Heartbreak", "Courage", "Passion", "Victory", "Rebellion", "Grief", "Angst", "Introspection"],

    "Demi_Lovato": ["Heartbreak", "Empowerment", "Resilience", "Love", "Loneliness", "Confidence", "Strength", "Healing", "Grief", "Regret", "Hope", "Vulnerability", "Desire", "Passion", "Anger", "Freedom", "Self-Reflection"],

    "Beyoncé": ["Confidence", "Empowerment", "Love", "Strength", "Resilience", "Heartbreak", "Joy", "Fierceness", "Anger", "Independence", "Hope", "Passion", "Desire", "Romance", "Inspiration", "Sisterhood", "Celebration"],

    "Olivia_Rodrigo": ["Heartbreak", "Sadness", "Vulnerability", "Anger", "Youth", "Rebellion", "Love", "Desperation", "Regret", "Loneliness", "Nostalgia", "Empowerment", "Passion", "Confidence", "Reflection", "Hope", "Bittersweetness"],

    "Taylor_Swift": ["Love", "Heartbreak", "Nostalgia", "Hope", "Self-Reflection", "Desire", "Romance", "Sadness", "Vulnerability", "Regret", "Strength", "Confusion", "Independence", "Empowerment", "Fear", "Reflection", "Healing"],

    "Coldplay": ["Hope", "Loneliness", "Love", "Yearning", "Nostalgia", "Desire", "Regret", "Empowerment", "Celebration", "Heartbreak", "Strength", "Fear", "Euphoria", "Peace", "Resilience", "Introspection", "Inspiration"],

    "Katy_Perry": ["Confidence", "Empowerment", "Playfulness", "Celebration", "Love", "Heartbreak", "Passion", "Fun", "Strength", "Romance", "Independence", "Rebellion", "Hope", "Loneliness", "Self-Expression", "Desire"],

    "Nicki_Minaj": ["Confidence", "Empowerment", "Rebellion", "Fierceness", "Self-Love", "Anger", "Strength", "Passion", "Desire", "Fun", "Independence", "Vulnerability", "Joy", "Celebration", "Romance", "Playfulness"]
}

# %%
import random

# Function to assign 2 random emotions to a song based on the artist
def assign_emotions_usa(artist):
    #random.seed(seed)  # Ensure reproducibility for the random choices

    # Format artist name and fetch the emotions list
    formatted_artist = lets_format_artist_name(artist)  # Format artist name
    emotions = artist_emotions_usa.get(formatted_artist, [])

    if len(emotions) == 0:
        return 'No emotion'  # If no emotions are found for the artist, return 'No emotion'

    # If there are fewer than 2 emotions, repeat them to ensure 2 emotions are available
    if len(emotions) < 2:
        emotions = emotions * 2  # Repeat the emotions to fill up the list

    # Randomly select 2 emotions for this song from the available emotions
    return ', '.join(random.sample(emotions, 2))  # Randomly select 2 emotions and return as a string

# %%
#df_problem_ind["Emotion"] = df_problem_ind["Artist"].apply(lambda x: assign_emotions(x))
df_problem_usa["Emotion"] = df_problem_usa["Artist"].apply(lambda x: assign_emotions_usa(x))

# %%
df_problem_usa.head()
# Out:
#           Artist Country           Song  \
# 0      Lady Gaga     USA     Sour Candy
# 1   Taylor Swift     USA  The Albatross
# 2  Justin Bieber     USA        Hold On
# 3       Dua Lipa     USA     Be the One
# 4        Beyoncé     USA         Heated
#
#                                            url                    Emotion
# 0  https://www.youtube.com/watch?v=fnPn6At3v28      Introspection, Desire
# 1  https://www.youtube.com/watch?v=4wOsiM2T_xc  Reflection, Vulnerability
# 2  https://www.youtube.com/watch?v=LWeiydKl0mU   Faithfulness, Resilience
# 3  https://www.youtube.com/watch?v=-rey3m8SWQI       Strength, Resilience
# 4  https://www.youtube.com/watch?v=o3WqRPM6M0A    Fierceness, Celebration

# %%
df_problem_usa["Emotion"].value_counts()
# Out:
# Emotion
# Hope, Vulnerability            4
# Nostalgia, Romance             3
# Vulnerability, Empowerment     3
# Loneliness, Hope               2
# Isolation, Hope                2
#                               ..
# Loneliness, Yearning           1
# Hope, Empowerment              1
# Revenge, Desire                1
# Self-Reflection, Confidence    1
# Vulnerability, Confidence      1
# Name: count, Length: 207, dtype: int64

# %%
df_problem_usa.isna().sum()
# Out:
# Artist     0
# Country    0
# Song       0
# url        0
# Emotion    0
# dtype: int64

# %%
len(df_problem_usa)
# Out:
# 231

# %%
# 440 - 231 = 209

# %%
df_usa_1 = df_usa[df_usa["Emotion"] != "Page not found"]
df_usa_2 = df_usa_1[df_usa_1["Emotion"] != "NO EMOTION"]
len(df_usa_2)
# Out:
# 209

# %%
df_usa_2.head()
# Out:
#              Artist Country                  Song  \
# 3             Drake     USA        Virginia Beach
# 4     Billie Eilish     USA       Bad Guy (Remix)
# 6     Billie Eilish     USA  What Was I Made For?
# 13       Bruno Mars     USA   Leave the Door Open
# 18  Imagine Dragons     USA                  Zero
#
#                                             url         Emotion
# 3   https://www.youtube.com/watch?v=k20wnICXpps       Folk, Pop
# 4   https://www.youtube.com/watch?v=9Wb-oJ6WVy0        Pop, Fun
# 6   https://www.youtube.com/watch?v=cW8VLC9nnTo   Hope, Success
# 13  https://www.youtube.com/watch?v=adLGHcj_fmA       Soul, Pop
# 18  https://www.youtube.com/watch?v=j60ClcNYWu4  Confusion, Fun

# %%
df_usa_final = pd.concat([df_usa_2,df_problem_usa],ignore_index=True)
df_usa_final
# Out:
#               Artist Country                          Song  \
# 0              Drake     USA                Virginia Beach
# 1      Billie Eilish     USA               Bad Guy (Remix)
# 2      Billie Eilish     USA          What Was I Made For?
# 3         Bruno Mars     USA           Leave the Door Open
# 4    Imagine Dragons     USA                          Zero
# ..               ...     ...                           ...
# 435            Drake     USA                       Lurkin’
# 436    Ariana Grande     USA         Sweetener (2024 Live)
# 437           Eminem     USA    Rap God (Extended Version)
# 438            Drake     USA      Falling Back (2023 Live)
# 439          Rihanna     USA  What’s My Name? (2024 Remix)
#
#                                              url  \
# 0    https://www.youtube.com/watch?v=k20wnICXpps
# 1    https://www.youtube.com/watch?v=9Wb-oJ6WVy0
# 2    https://www.youtube.com/watch?v=cW8VLC9nnTo
# 3    https://www.youtube.com/watch?v=adLGHcj_fmA
# ...

# %%
df_usa_final.isna().sum()
# Out:
# Artist     0
# Country    0
# Song       0
# url        0
# Emotion    0
# dtype: int64

# %%
df_music_emotion = pd.concat([df_india_final,df_usa_final],ignore_index=True)
len(df_music_emotion)
# Out:
# 840

# %%
df_music_emotion["Language"] = df_music_emotion["Country"].apply(lambda x: "English" if x == "USA" else "Hindi" if x == "India" else "Unknown")

# %%
df_music_emotion
# Out:
#             Artist Country                          Song  \
# 0       Sonu Nigam   India                  Kuch Na Kaho
# 1      A.R. Rahman   India                Chand Sifarish
# 2          B Praak   India                        Qareeb
# 3     Daler Mehndi   India               Tunak Tunak Tun
# 4      Pankaj Udas   India               Rang De Basanti
# ..             ...     ...                           ...
# 835          Drake     USA                       Lurkin’
# 836  Ariana Grande     USA         Sweetener (2024 Live)
# 837         Eminem     USA    Rap God (Extended Version)
# 838          Drake     USA      Falling Back (2023 Live)
# 839        Rihanna     USA  What’s My Name? (2024 Remix)
#
#                                              url  \
# 0    https://www.youtube.com/watch?v=_VywEtukPo0
# 1    https://www.youtube.com/watch?v=zWEOx7TSM6I
# 2    https://www.youtube.com/watch?v=44BHGfFGHTg
# 3    https://www.youtube.com/watch?v=IFP3Jc5ztgg
# ...

# %%
df_music_emotion.isna().sum()
# Out:
# Artist      0
# Country     0
# Song        0
# url         0
# Emotion     0
# Language    0
# dtype: int64

# %%
df_music_emotion["Language"].value_counts()
# Out:
# Language
# English    440
# Hindi      400
# Name: count, dtype: int64

# %%
df_music_emotion = df_music_emotion.sample(frac=1).reset_index(drop=True)

# %%
df_music_emotion
# Out:
#              Artist Country                 Song  \
# 0       Pankaj Udas   India  Akele Hum Akele Tum
# 1       Neeti Mohan   India       Main Wahi Hoon
# 2       Nicki Minaj     USA              Chun-Li
# 3          Dua Lipa     USA               Potion
# 4      Armaan Malik   India  Main Hoon Hero Tera
# ..              ...     ...                  ...
# 835     Neeti Mohan   India         Teri Deewani
# 836       Lady Gaga     USA    Dance in the Dark
# 837  Shreya Ghoshal   India        Hasi Ban Gaye
# 838   Jonita Gandhi   India               Kabira
# 839  Sachin Sanghvi   India   Pyaar Ka Punchnama
#
#                                              url  \
# 0    https://www.youtube.com/watch?v=9umE4vu-ros
# 1    https://www.youtube.com/watch?v=0CtAfovnDsw
# 2    https://www.youtube.com/watch?v=Wpm07-BGJnE
# 3    https://www.youtube.com/watch?v=FFV6t4Dl_zQ
# 4    https://www.youtube.com/watch?v=6aOAskg67Vw
# ..                                           ...
# ...

# %%
df_music_emotion.to_csv("MY_MUSIC_EMOTION.csv",index=False)

# %%
df_music_emotion.head()
# Out:
#          Artist Country                 Song  \
# 0   Pankaj Udas   India  Akele Hum Akele Tum
# 1   Neeti Mohan   India       Main Wahi Hoon
# 2   Nicki Minaj     USA              Chun-Li
# 3      Dua Lipa     USA               Potion
# 4  Armaan Malik   India  Main Hoon Hero Tera
#
#                                            url                   Emotion  \
# 0  https://www.youtube.com/watch?v=9umE4vu-ros          House, Happiness
# 1  https://www.youtube.com/watch?v=0CtAfovnDsw                 Nostalgic
# 2  https://www.youtube.com/watch?v=Wpm07-BGJnE            Crossover, Pop
# 3  https://www.youtube.com/watch?v=FFV6t4Dl_zQ             Love, Healing
# 4  https://www.youtube.com/watch?v=6aOAskg67Vw  Healing, Self-Reflection
#
#   Language
# 0    Hindi
# 1    Hindi
# 2  English
# 3  English
# 4    Hindi
